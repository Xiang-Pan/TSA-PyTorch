# %%
import Stemmer

# %%
stemmer = Stemmer.Stemmer('english')

# %%
import numpy as np

# %%
train=np.load('./datasets/processed/train-laptop.npy',allow_pickle=True)

# %%
test=np.load('./datasets/processed/test-laptop.npy',allow_pickle=True)

# %%
train.shape
# Out:
# (2328,)

# %%
test.shape
# Out:
# (638,)

# %%
alldata=np.concatenate((train,test))

# %%
alldata.shape
# Out:
# (2966,)

# %%
target_list=[]
stem_list=[]
for data in alldata:
    target_list.append(data['text_aspect'])
    s=stemmer.stemWord(data['text_aspect'])
#     target_list.append(s)
#     stem_list
    stem_list.append(s)

# %%
len(set(target_list))
# Out:
# 1185

# %%
target_list=stem_list

# %%
len(set(stem_list))
# Out:
# 1088

# %%
len(target_list)
# Out:
# 2966

# %%
target_set=set(target_list)

# %%
len(target_set)
# Out:
# 1088

# %%
target_set
# Out:
# {'web brows',
#  'windows 8',
#  'start menu',
#  'windows 7 ultim',
#  'download',
#  'booting up',
#  "sony 'certified' technician",
#  'cooling system',
#  'fan nois',
#  'securitysoftwar',
#  'manual',
#  'harddriv',
#  'time respons',
#  'retina display display',
#  'dock',
#  'hook to my wireless network',
#  'printer',
#  'windows 7 profession',
#  'thunderbolt',
#  'lightscrib',
#  'cpu',
#  'tech issu',
#  'drive',
#  'talking to a technician',
#  'charger',
#  'power suppli',
#  'content cr',
#  'apple navig',
#  'customer support',
#  'rubber enclosur',
#  'iweb',
#  'fingerprint read',
#  'hinge design',
#  'quicklook',
#  'pictur',
#  'one of the program',
#  '2.9ghz dual-core i7 chip',
#  'depend',
#  'included program',
#  'internal cd dr',
#  'microsoft office for the mac',
#  'screen/video resolut',
#  'surf',
#  'mac snow leopard o/',
#  'system clock',
#  'installation tim',
#  'expens',
#  'video edit',
#  'agent',
#  'desktop background',
#  'built in camera',
# ...

# %% [markdown]
# # split

# %%
target_dict=dict()
for i in range(len(alldata)):
    target=alldata[i]['text_aspect']
    if target not in target_dict:
        l=list()
        l.append(i)
        target_dict[target]=l
    else:
        l=target_dict[target]
        l.append(i)
        target_dict[target]=l

# %%
target_dict
# Out:
# {'cord': [0, 1589],
#  'battery life': [1,
#   21,
#   99,
#   111,
#   112,
#   121,
#   183,
#   202,
#   332,
#   450,
#   472,
#   477,
#   557,
#   583,
#   584,
#   601,
#   604,
#   623,
#   722,
#   844,
#   859,
#   898,
#   914,
#   920,
#   960,
#   961,
#   1120,
#   1131,
#   1149,
#   1195,
#   1239,
#   1271,
#   1400,
#   1473,
#   1526,
#   1536,
#   1544,
#   1584,
#   1613,
#   1670,
#   1751,
#   1815,
#   1822,
#   1940,
#   1981,
#   1995,
#   2001,
#   2036,
#   2169,
#   2204,
#   2258,
#   2275,
#   2294,
#   2343,
#   2353,
#   2455,
#   2483,
#   2903,
#   2926],
#  'service center': [2, 1288, 1483, 1657],
#  '"sales" team': [3],
#  'tech guy': [4],
#  'quality': [5,
#   68,
#   267,
#   331,
#   386,
#   568,
#   669,
#   798,
#   864,
#   912,
#   1121,
#   1425,
#   1477,
#   1527,
#   1752,
#   1814,
#   1840,
#   2009,
#   2073,
#   2089,
#   2112,
#   2113,
#   2215,
#   2377,
#   2479,
#   2485],
#  'gui': [6, 15],
#  'applications': [7,
#   205,
# ...

# %%
target_dict
# Out:
# {'cord': [0, 1589],
#  'battery life': [1,
#   21,
#   99,
#   111,
#   112,
#   121,
#   183,
#   202,
#   332,
#   450,
#   472,
#   477,
#   557,
#   583,
#   584,
#   601,
#   604,
#   623,
#   722,
#   844,
#   859,
#   898,
#   914,
#   920,
#   960,
#   961,
#   1120,
#   1131,
#   1149,
#   1195,
#   1239,
#   1271,
#   1400,
#   1473,
#   1526,
#   1536,
#   1544,
#   1584,
#   1613,
#   1670,
#   1751,
#   1815,
#   1822,
#   1940,
#   1981,
#   1995,
#   2001,
#   2036,
#   2169,
#   2204,
#   2258,
#   2275,
#   2294,
#   2343,
#   2353,
#   2455,
#   2483,
#   2903,
#   2926],
#  'service center': [2, 1288, 1483, 1657],
#  '"sales" team': [3],
#  'tech guy': [4],
#  'quality': [5,
#   68,
#   267,
#   331,
#   386,
#   568,
#   669,
#   798,
#   864,
#   912,
#   1121,
#   1425,
#   1477,
#   1527,
#   1752,
#   1814,
#   1840,
#   2009,
#   2073,
#   2089,
#   2112,
#   2113,
#   2215,
#   2377,
#   2479,
#   2485],
#  'gui': [6, 15],
#  'applications': [7,
#   205,
# ...

# %%
train_val_dict = {key: value for i, (key, value) in enumerate(target_dict.items()) if i % 5 != 0}
test_dict = {key: value for i, (key, value) in enumerate(target_dict.items()) if i % 5 == 0}

# %%
len(train_val_dict)
# Out:
# 948

# %%
len(test_dict)
# Out:
# 237

# %%
train_dict = {key: value for i, (key, value) in enumerate(train_val_dict.items()) if i % 20 != 0}
val_dict = {key: value for i, (key, value) in enumerate(train_val_dict.items()) if i % 20 == 0}

# %%
train_index=[]
for key,value in train_dict.items():
    train_index.extend(value)
train_index
# Out:
# [2,
#  1288,
#  1483,
#  1657,
#  3,
#  4,
#  6,
#  15,
#  7,
#  205,
#  633,
#  725,
#  902,
#  979,
#  1052,
#  1282,
#  1497,
#  1660,
#  1758,
#  2039,
#  2092,
#  2146,
#  2179,
#  2185,
#  2208,
#  2228,
#  2539,
#  8,
#  104,
#  107,
#  136,
#  145,
#  175,
#  177,
#  258,
#  279,
#  281,
#  346,
#  419,
#  422,
#  462,
#  589,
#  637,
#  657,
#  667,
#  857,
#  876,
#  915,
#  965,
#  991,
#  1010,
#  1088,
#  1156,
#  1225,
#  1237,
#  1247,
#  1253,
#  1427,
#  1559,
#  1561,
#  1600,
#  1651,
#  1653,
#  1655,
#  1696,
#  1754,
#  1761,
#  1798,
#  1868,
#  1877,
#  1923,
#  1956,
#  1969,
#  2081,
#  2094,
#  2126,
#  2156,
#  2225,
#  2266,
#  2310,
#  2312,
#  2337,
#  2419,
#  2540,
#  2541,
#  2558,
#  2609,
#  2656,
#  2671,
#  2677,
#  9,
#  1254,
#  2491,
#  2559,
#  2681,
#  11,
#  12,
#  1722,
#  13,
#  2694,
#  16,
#  38,
#  182,
#  230,
#  250,
#  367,
#  405,
#  425,
#  470,
#  508,
#  541,
#  622,
#  656,
#  678,
#  751,
#  757,
#  785,
#  794,
#  839,
# ...

# %%
test_index=[]
for key,value in test_dict.items():
    test_index.extend(value)
test_index
# Out:
# [0,
#  1589,
#  5,
#  68,
#  267,
#  331,
#  386,
#  568,
#  669,
#  798,
#  864,
#  912,
#  1121,
#  1425,
#  1477,
#  1527,
#  1752,
#  1814,
#  1840,
#  2009,
#  2073,
#  2089,
#  2112,
#  2113,
#  2215,
#  2377,
#  2479,
#  2485,
#  10,
#  14,
#  44,
#  49,
#  303,
#  435,
#  480,
#  562,
#  588,
#  670,
#  672,
#  749,
#  888,
#  940,
#  963,
#  1155,
#  1161,
#  1183,
#  1221,
#  1246,
#  1255,
#  1267,
#  1283,
#  1370,
#  1406,
#  1577,
#  1616,
#  1639,
#  1715,
#  1860,
#  2029,
#  2033,
#  2167,
#  2268,
#  2271,
#  2340,
#  2373,
#  2443,
#  2478,
#  2506,
#  2651,
#  2745,
#  2853,
#  2870,
#  2884,
#  2890,
#  17,
#  23,
#  28,
#  113,
#  338,
#  555,
#  636,
#  872,
#  1150,
#  1355,
#  1500,
#  1662,
#  1689,
#  1907,
#  2012,
#  2509,
#  2523,
#  2532,
#  2741,
#  33,
#  185,
#  197,
#  238,
#  297,
#  306,
#  322,
#  348,
#  358,
#  377,
#  430,
#  453,
#  662,
#  709,
#  761,
#  959,
#  1002,
#  1003,
#  1009,
#  1070,
#  1110,
#  1190,
#  1219,
#  1303,
#  1422,
# ...

# %%
val_index=[]
for key,value in val_dict.items():
    val_index.extend(value)
val_index
# Out:
# [1,
#  21,
#  99,
#  111,
#  112,
#  121,
#  183,
#  202,
#  332,
#  450,
#  472,
#  477,
#  557,
#  583,
#  584,
#  601,
#  604,
#  623,
#  722,
#  844,
#  859,
#  898,
#  914,
#  920,
#  960,
#  961,
#  1120,
#  1131,
#  1149,
#  1195,
#  1239,
#  1271,
#  1400,
#  1473,
#  1526,
#  1536,
#  1544,
#  1584,
#  1613,
#  1670,
#  1751,
#  1815,
#  1822,
#  1940,
#  1981,
#  1995,
#  2001,
#  2036,
#  2169,
#  2204,
#  2258,
#  2275,
#  2294,
#  2343,
#  2353,
#  2455,
#  2483,
#  2903,
#  2926,
#  29,
#  60,
#  91,
#  1511,
#  128,
#  173,
#  216,
#  253,
#  293,
#  406,
#  1015,
#  1259,
#  2110,
#  343,
#  390,
#  440,
#  483,
#  536,
#  590,
#  661,
#  1869,
#  707,
#  760,
#  831,
#  909,
#  2453,
#  976,
#  2100,
#  2181,
#  2237,
#  2425,
#  2439,
#  2633,
#  1036,
#  1744,
#  1094,
#  1162,
#  1217,
#  1502,
#  1588,
#  1609,
#  1621,
#  1687,
#  1745,
#  1746,
#  1943,
#  1944,
#  1973,
#  1974,
#  1983,
#  1295,
#  2531,
#  1356,
#  1428,
#  1495,
#  1582,
#  1664,
#  1749,
# ...

# %%
# np.save('train-restaurant.npy',alldata[train_index])
np.save('./datasets/resplit/train-laptop.npy',alldata[train_index])

# %%
len(train_index)
# Out:
# 2296

# %%
np.save('./datasets/resplit/test-laptop.npy',alldata[test_index])

# %%
np.save('./datasets/resplit/valid-laptop.npy',alldata[val_index])

# %%
len(val_index)
# Out:
# 134

# %%
len(train_index)
# Out:
# 2997

# %%
len(test_index)
# Out:
# 536
